# %% [markdown]
# # Part 1

# %% [markdown]
# ## Prepare the project

# %%
# Imports
import numpy as np
import pandas as pd
# for visuals
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter


from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %% [markdown]
# ### Create Data Frame

# %%
# create the dataframe
# load data
filename = 'option_A_clustering_df - option_A_clustering_df.csv'
housing_df = pd.read_csv(filename)

# %%
# check the dataframe loaded correctly
housing_df.head()
# Out:
#    SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  SqFtUpperFloor  \
# 0     400000          1590              0             0               0
# 1     474250          1390              0             0               0
# 2     667950          1010              0          1515               0
# 3     659000           660              0           540               0
# 4     656500          2310              0             0               0
#
#    SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  SqFtGarageBasement  \
# 0           3180             1590             1590                   0
# 1           2200              810              810                   0
# 2           2525                0                0                   0
# 3           1820              620              620                   0
# 4           2310                0                0                   0
#
#    SqFtGarageAttached  ...  SqFtEnclosedPorch  SqFtDeck  BrickStone  Bedrooms  \
# ...

# %%
# look at the data info
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4944 entries, 0 to 4943
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SalePrice           4944 non-null   int64
#  1   SqFt1stFloor        4944 non-null   int64
#  2   SqFtHalfFloor       4944 non-null   int64
#  3   SqFt2ndFloor        4944 non-null   int64
#  4   SqFtUpperFloor      4944 non-null   int64
#  5   SqFtTotLiving       4944 non-null   int64
#  6   SqFtTotBasement     4944 non-null   int64
#  7   SqFtFinBasement     4944 non-null   int64
#  8   SqFtGarageBasement  4944 non-null   int64
#  9   SqFtGarageAttached  4944 non-null   int64
#  10  DaylightBasement    4944 non-null   int64
#  11  SqFtOpenPorch       4944 non-null   int64
#  12  SqFtEnclosedPorch   4944 non-null   int64
#  13  SqFtDeck            4944 non-null   int64
#  14  BrickStone          4944 non-null   int64
#  15  Bedrooms            4944 non-null   int64
# ...

# %% [markdown]
# -  There are no obvious problems with column datatypes

# %%
#will drop longgitude and latitude columns because they are not relevant
#housing_df = housing_df.drop('Longitude', axis='columns')

# %%
#housing_df = housing_df.drop('Latitude', axis='columns')

# %%
# check that they were dropped
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4944 entries, 0 to 4943
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SalePrice           4944 non-null   int64
#  1   SqFt1stFloor        4944 non-null   int64
#  2   SqFtHalfFloor       4944 non-null   int64
#  3   SqFt2ndFloor        4944 non-null   int64
#  4   SqFtUpperFloor      4944 non-null   int64
#  5   SqFtTotLiving       4944 non-null   int64
#  6   SqFtTotBasement     4944 non-null   int64
#  7   SqFtFinBasement     4944 non-null   int64
#  8   SqFtGarageBasement  4944 non-null   int64
#  9   SqFtGarageAttached  4944 non-null   int64
#  10  DaylightBasement    4944 non-null   int64
#  11  SqFtOpenPorch       4944 non-null   int64
#  12  SqFtEnclosedPorch   4944 non-null   int64
#  13  SqFtDeck            4944 non-null   int64
#  14  BrickStone          4944 non-null   int64
#  15  Bedrooms            4944 non-null   int64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Display the number of duplicate rows
print(f'There are {housing_df.duplicated().sum()} duplicate rows.')
# Out:
# There are 29 duplicate rows.

# %%
# Drop the duplicated rows
housing_df.drop_duplicates(inplace = True)
housing_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are no duplicated rows.

# %%
## check data for inconsistencies
housing_df.describe()
# Out:
#           SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  \
# count  4.915000e+03   4915.000000    4915.000000   4915.000000
# mean   6.645444e+05   1179.083418      51.959919    347.439064
# std    2.985774e+05    444.925946     174.811762    544.865685
# min    6.000000e+04    260.000000       0.000000      0.000000
# 25%    4.500000e+05    880.000000       0.000000      0.000000
# 50%    6.300000e+05   1170.000000       0.000000      0.000000
# 75%    7.899500e+05   1450.000000       0.000000    580.000000
# max    1.998000e+06   3600.000000    2000.000000   3010.000000
#
#        SqFtUpperFloor  SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  \
# count     4915.000000    4915.000000      4915.000000      4915.000000
# mean        26.524517    1937.448627       596.627874       334.984334
# std        114.672475     765.663840       567.978214       423.696071
# min          0.000000     300.000000         0.000000         0.000000
# ...

# %%
# Check for missing values
housing_df.isna().sum()
# Out:
# SalePrice             0
# SqFt1stFloor          0
# SqFtHalfFloor         0
# SqFt2ndFloor          0
# SqFtUpperFloor        0
# SqFtTotLiving         0
# SqFtTotBasement       0
# SqFtFinBasement       0
# SqFtGarageBasement    0
# SqFtGarageAttached    0
# DaylightBasement      0
# SqFtOpenPorch         0
# SqFtEnclosedPorch     0
# SqFtDeck              0
# BrickStone            0
# Bedrooms              0
# BathHalfCount         0
# Bath3qtrCount         0
# BathFullCount         0
# YrBuilt               0
# Longitude             0
# Latitude              0
# dtype: int64

# %% [markdown]
# - There are no missing values

# %% [markdown]
# ## Apply PCA

# %%
# Instantiate Standard Scaler
scaler = StandardScaler()
# Fit & transform data.
scaled_x = scaler.fit_transform(housing_df)

# %%
# Instantiate PCA
pca = PCA()
pca.fit(scaled_x)
# Out:
# PCA()

# %%
# Lets visual the cummulative sum of the variances 

plt.style.use("seaborn")
plt.figure(figsize=(15,8))
exp_var = pd.Series(pca.explained_variance_ratio_)

exp_var.plot(kind="bar", alpha=0.7) # plot bar chart

# Calculate the amount of variance explained added by each additional component
total = 0
var_ls = []
for x in exp_var:
    total = total+x
    var_ls.append(total)

pd.Series(var_ls).plot(marker="o", alpha=0.7) #plot line chart of increasing variances
plt.xlabel("Principle Components", fontsize="x-large")
plt.ylabel("Percentage Variance Explained", fontsize="x-large")
plt.title("Housing Data Set Scree Plot", fontsize="xx-large")
plt.show();
# Out:
# C:\Users\Elizabeth Spreng\AppData\Local\Temp\ipykernel_26668\649455013.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
# The amount of variance that each PCA explains is 
var = pca.explained_variance_ratio_
var
# Out:
# array([1.82618503e-01, 1.46155157e-01, 1.03438910e-01, 7.45608603e-02,
#        5.39902771e-02, 4.92014842e-02, 4.37685367e-02, 4.25459322e-02,
#        4.18019731e-02, 4.04515988e-02, 3.74499039e-02, 3.20301066e-02,
#        2.93756804e-02, 2.76045321e-02, 2.03081730e-02, 2.02289132e-02,
#        1.57168978e-02, 1.41149290e-02, 1.02765199e-02, 8.66017601e-03,
#        5.64949477e-03, 5.14411980e-05])

# %%
# Cumulative variance 
var1 = np.cumsum(np.round(var,decimals = 4))
var1
# Out:
# array([0.1826, 0.3288, 0.4322, 0.5068, 0.5608, 0.61  , 0.6538, 0.6963,
#        0.7381, 0.7786, 0.816 , 0.848 , 0.8774, 0.905 , 0.9253, 0.9455,
#        0.9612, 0.9753, 0.9856, 0.9943, 0.9999, 1.    ])

# %%
# Creating dataframe for further clusering algorithms
pcs = pca.fit_transform(scaled_x)

pca_df = pd.DataFrame(pcs)
pca_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  3.347729 -2.260362 -1.815828 -2.607854  1.681881  1.431365  0.756302
# 1 -0.075451 -1.627671 -0.285838 -0.233689 -0.891536  1.164128  0.637209
# 2  1.975537  3.522097  0.377673 -0.528789 -1.376101 -0.103054  0.042899
# 3 -0.064434 -0.237222  1.768253  0.054178 -2.057059  0.437445  0.132642
# 4  0.670412  1.415528 -1.447696  0.176401  0.755629 -0.205021  0.044512
#
#          7         8         9   ...        12        13        14        15  \
# 0 -0.758104 -0.651682 -1.747305  ... -1.267993  0.344664  0.371771 -0.078494
# 1  0.284119 -1.612888  0.368829  ... -1.083736 -0.279412  0.326921 -0.461280
# 2  0.513576  0.149502 -0.284407  ...  0.204939  0.272960 -0.150591 -0.596628
# 3 -0.379558 -0.649809  0.102747  ... -0.303652  0.212459 -0.260068  0.278763
# 4 -1.051790 -0.672804  2.303502  ...  0.629448 -0.043203  0.834358  0.826657
#
#          16        17        18        19        20        21
# ...

# %% [markdown]
# - Based on the scree plot, and keeping the variance at 80%,  the principle components will be at 10. I used the website to help with this section https://365datascience.com/tutorials/python-tutorials/pca-k-means/

# %%
# create the PCA dataframe
pca = PCA(n_components =10)

# %%
pca.fit(housing_df)
# Out:
# PCA(n_components=10)

# %%
#save the scores
scores_pca = pca.transform(housing_df)

# %%
# use kmeans on PCA scaled data
wcss =[]

for i in range(2, 10):
    kmeans_pca=KMeans(n_clusters =i, init ='k-means++',random_state = 42)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
# plot graph
plt.figure(figsize = (10,8))
plt.plot(range(2,10), wcss, marker ='o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel ('WCSS')
plt.title('Kmeans with PCA clustering')
plt.show()

# %% [markdown]
# -From the PCA and Kmeans the clusters are 4.

# %% [markdown]
# ## K Means

# %% [markdown]
# ### Elbow Plot

# %%
# define a range of values of k to evaluate for inertia and empty list
ks = range(2, 10)
inertias = []

# for each value for k
for k in ks:
  
  # fit and run the model,
  km = KMeans(n_clusters=k)
  km.fit(scaled_x)
  inertias.append(km.inertia_)

# and plot the results
plt.plot(ks, inertias)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - From the elbow  plot, the best number of cluster is 4.

# %% [markdown]
# ### Silhouette Score

# %%
# define a range of values of k to evaluate for silhouette score and empty list
ks = range(2, 10)
sils = []

# for each value for k
for k in ks:

  # fit and run the model,
  km = KMeans(n_clusters=k)
  km.fit(scaled_x)
  sils.append(silhouette_score(scaled_x, km.labels_))



# and plot the results
plt.plot(ks, sils)
plt.xlabel('no of clusters')
plt.ylabel('silhouette scoare')
plt.show()

# %% [markdown]
# - From this graph the best number of clusters is 6.

# %% [markdown]
# ### Compare Silhouette scores based on  two models

# %%
# instantiate a KMeans model with the value for k based on elbow method 
km_optioneb = KMeans(n_clusters=4, random_state=42)
km_optioneb.fit(scaled_x)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# display the silhouette score based on clusters =4
silhouette_score(scaled_x, km_optioneb.labels_)
# Out:
# 0.17512416146275603

# %%
# instantiate a KMeans model with the value for k based on silhoutte method 
km_sil = KMeans(n_clusters=6, random_state=42)
km_sil.fit(scaled_x)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
# display the silhouette score based on clusters =5
silhouette_score(scaled_x, km_sil.labels_)
# Out:
# 0.18134088337701584

# %% [markdown]
# - From these two options I will go with the cluster of 4 based on simplifying the data, even thought the silhouette score is slightly higher for the silhouette method.

# %% [markdown]
# ## Final Model and Clustering the Data

# %%
# Create final model based on clusters =5
km = KMeans(n_clusters=4, random_state=42)
km.fit(scaled_x)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# add a column to the dataframe to add the cluster label as you fit and predict x 
housing_df['cluster'] = km.labels_

# %%
housing_df = pd.DataFrame(housing_df, columns = housing_df.columns)

# %%
# examine your dataframe with .head()
housing_df.head()
# Out:
#    SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  SqFtUpperFloor  \
# 0     400000          1590              0             0               0
# 1     474250          1390              0             0               0
# 2     667950          1010              0          1515               0
# 3     659000           660              0           540               0
# 4     656500          2310              0             0               0
#
#    SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  SqFtGarageBasement  \
# 0           3180             1590             1590                   0
# 1           2200              810              810                   0
# 2           2525                0                0                   0
# 3           1820              620              620                   0
# 4           2310                0                0                   0
#
#    SqFtGarageAttached  ...  SqFtDeck  BrickStone  Bedrooms  BathHalfCount  \
# ...

# %% [markdown]
# ## Investigate the clusters

# %%
# Use .groupby() to investigate the average .
cluster_groups = housing_df.groupby('cluster')

# %%
# calcualte the average values for each cluster for each column
cluster_means = cluster_groups.mean()
cluster_means
# Out:
#              SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  \
# cluster
# 0        535441.334704   1198.650386      95.829306     64.987147
# 1        700563.034898    562.196149       6.309266    556.848375
# 2        716037.064815   1418.153846      29.830484     70.339031
# 3        867099.687075   1368.091156      29.755102   1387.436735
#
#          SqFtUpperFloor  SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  \
# cluster
# 0              0.000000    1440.407712       361.093573        84.719794
# 1            148.950662    1537.246691       375.456077       266.551143
# 2              0.000000    2334.504274      1248.960826       816.558405
# 3              8.965986    2946.763265       223.882993       154.715646
#
#          SqFtGarageBasement  SqFtGarageAttached  ...  SqFtEnclosedPorch  \
# cluster                                          ...
# 0                 28.699229          155.235476  ...           7.681234
# ...

# %% [markdown]
# - Create overview of all means visuals

# %%
#create a copy of the dataset
clustering_df = housing_df.copy()

#do not have to drop target column
clustering_df.head()
# Out:
#    SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  SqFtUpperFloor  \
# 0     400000          1590              0             0               0
# 1     474250          1390              0             0               0
# 2     667950          1010              0          1515               0
# 3     659000           660              0           540               0
# 4     656500          2310              0             0               0
#
#    SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  SqFtGarageBasement  \
# 0           3180             1590             1590                   0
# 1           2200              810              810                   0
# 2           2525                0                0                   0
# 3           1820              620              620                   0
# 4           2310                0                0                   0
#
#    SqFtGarageAttached  ...  SqFtDeck  BrickStone  Bedrooms  BathHalfCount  \
# ...

# %%
# fit the new dataset
scaler = StandardScaler()

clustering_df = scaler.fit_transform(clustering_df)

clustering_df = pd.DataFrame(clustering_df, columns = housing_df.columns)

# %%
# Check the shape
clustering_df.shape
# Out:
# (4915, 23)

# %%
# look at the means data
kmeans = KMeans(n_clusters = 4, random_state = 42) 
kmeans.fit(clustering_df)

#Creating Clusters in dataframe
dfcluster = housing_df.copy()
dfcluster["cluster"] = kmeans.labels_

#Printing cluster groups
cluster_groups2 = dfcluster.groupby('cluster', as_index=False).mean()
cluster_groups2
# Out:
#    cluster      SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  \
# 0        0  700563.034898    562.196149       6.309266    556.848375
# 1        1  716037.064815   1418.153846      29.830484     70.339031
# 2        2  867099.687075   1368.091156      29.755102   1387.436735
# 3        3  535441.334704   1198.650386      95.829306     64.987147
#
#    SqFtUpperFloor  SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  \
# 0      148.950662    1537.246691       375.456077       266.551143
# 1        0.000000    2334.504274      1248.960826       816.558405
# 2        8.965986    2946.763265       223.882993       154.715646
# 3        0.000000    1440.407712       361.093573        84.719794
#
#    SqFtGarageBasement  ...  SqFtEnclosedPorch    SqFtDeck  BrickStone  \
# 0          104.377858  ...          16.281588  299.560770    0.481348
# 1          238.179487  ...           5.920940  203.675926    8.089031
# ...

# %%
# Visualize means 
fig, axes = plt.subplots(4,6, figsize = (25, 20))
# fig is an array of dimensions 6,4.  axes.ravel() will flatten it to 4*6,1
axes = axes.ravel()
# Loop over columns and plot each in a separate figure, skip 'cluster' column
for i, col in enumerate(cluster_means.columns[1:]):
  axes[i].bar(cluster_groups2['cluster'], cluster_groups2[col])
  axes[i].set_title(f'Mean {col}')

# %%
# Get all statistics for one column for each cluster
housing_df.groupby('cluster')['SalePrice'].describe()
# Out:
#           count           mean            std       min       25%       50%  \
# cluster
# 0         716.0  875669.153631  360576.407158  165000.0  626692.0  774950.0
# 1         777.0  703784.194337  179444.295605  195000.0  604800.0  689900.0
# 2        1417.0  714904.812279  308461.524487   75000.0  485000.0  659500.0
# 3        1944.0  535616.093107  243391.735589   60000.0  350000.0  499950.0
#
#                 75%        max
# cluster
# 0        1058764.25  1998000.0
# 1         772000.00  1750250.0
# 2         865000.00  1980000.0
# 3         669250.00  1930000.0

# %%
## Explanatory visuals

# %%
# Visualize means 
fig, axes = plt.subplots(5,4, figsize = (20, 10))
# still working on this one
axes = axes.ravel()
# Loop over columns and plot each in a separate figure, skip 'cluster' column
for i, col in enumerate(housing_df.columns[1:]):
  axes[i].bar(housing_df['cluster'], housing_df[col])
  axes[i].set_title(f'Mean {col}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [228], line 7
#       5 # Loop over columns and plot each in a separate figure, skip 'cluster' column
#       6 for i, col in enumerate(housing_df.columns[1:]):
# ----> 7   axes[i].bar(housing_df['cluster'], housing_df[col])
#       8   axes[i].set_title(f'Mean {col}')
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
#using bar plot display each feature mean for the cluster

cluster_means.plot(subplots=True, kind='bar', 
                     figsize=(60,60), sharex=False,
                     layout=(8,5))
plt.tight_layout()

# %% [markdown]
# ## Overview from this clustering
# - Cluster 0: highest mean sale price and the highest square footage.
# - Cluster 1: have decks and the lowest amount of bedrooms and  total square footage and first floor footage
# - Cluster 2:  have the second nighest number of bedrooms and sale price close to cluster 1. They are mad of brick and have the highest number of porches and biggest basements
# - Cluster 3: least expensive mean price, least number of bathrooms

# %%
# Visualize means values of each column
cluster_means.plot(subplots=True, kind='bar', figsize=(20,150))
plt.tight_layout()

# %% [markdown]
# ## Explanatory Visual #1

# %%
# Looking at the big picture
fig, axes = plt.subplots(nrows = 2, figsize = (8,12))

sns.barplot(data=housing_df,x='cluster', y = 'SalePrice', errorbar = None, ax = axes[0])
axes[0].set_title('Sale price', fontsize = 20, fontweight = 'bold');
axes[0].set_xlabel('cluster', fontsize = 15, fontweight = 'bold')
axes[0].set_ylabel('Sale Price', fontsize = 15, fontweight = 'bold');

sns.barplot(data=housing_df,x='cluster', y = 'SqFtTotLiving', errorbar = None)
axes[1].set_title('Total Square Footage', fontsize = 20, fontweight = 'bold');
axes[1].set_xlabel('cluster', fontsize = 15, fontweight = 'bold')
axes[1].set_ylabel('Square Footage', fontsize = 15, fontweight = 'bold');

# %%
sns.barplot(data=housing_df,x='cluster', y = 'Brickstone', errorbar = None, ax = axes[0])
axes[0].set_title('Sale price', fontsize = 20, fontweight = 'bold');
axes[0].set_xlabel('cluster', fontsize = 15, fontweight = 'bold')
axes[0].set_ylabel('Sale Price', fontsize = 15, fontweight = 'bold');

# %% [markdown]
# - In these two bar plots, Cluster 3 has the highest sale price of 80K and highest square footage of 3000. The lowest price homes are in cluster 0 and these are also the smallest homes. Cluster 1 is almost 20K more than cluster 0, but not much bigger.

# %%
#Visual for race
fig, ax = plt.subplots(figsize=(15,10))

sns.barplot(data = housing_df, x = 'Bedrooms', y = 'SalePrice', hue ='cluster', errorbar=None)
plt.xticks(rotation = 55);
plt.xlabel("Bedrooms")
plt.ylabel("Sale Price in USD")

plt.title('Bedrooms and Sale Price')

def hundred_k(x,pos):
  """function for use with matplotlib FuncFormatter - formats money in millions"""
  return f'${x*1e-1:,.0f}K'

price_fmt_100k = FuncFormatter(hundred_k)

ax.yaxis.set_major_formatter(price_fmt_100k)

# %% [markdown]
# - This graph provides information about the sale price and bedrooms. In this graph clusters 2 and 3 have the highest prices and also are the only clusters with 7 and 8 bedrooms. Cluster 3 also does not have any 0-1 bedroom homes.
# - Homes with 2,3, 4 , and 5 bedrooms have sale price ranging  from 50K to 85K, but homes with 0-1 bedrooms range in price fro 38K to 65K.

# %% [markdown]
# # Part 2: Modeling

# %% [markdown]
# ## Set up Project

# %% [markdown]
# ### Import Libraries

# %%
#for regression metrics
from sklearn.metrics import mean_absolute_error, r2_score, \
mean_squared_error, precision_score, recall_score, accuracy_score, f1_score, \
ConfusionMatrixDisplay, classification_report

## for test/train split and machine learning
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import make_pipeline


# new libraries
import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense

# This is used to overcome an issue with setting up tensorflow in M1/M1 
# Suspect tensorflow-macos not very fit with GPU, use CPU only with
tf.config.set_visible_devices([], 'GPU')

# Set random seeds for consistent outcomes
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#show all results
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Create functions and visuals

# %%
def plot_history(history):
  """Takes a keras model learning history and plots each metric"""
  
  metrics = history.history.keys()
  
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()
        
def eval_regression(true, pred, name='Model'):
    """Evaluates true and predicted values from a regression model.  
    Outputs a dataframe of metrics"""
    scores = pd.DataFrame()
    scores['Model Name'] = [name]
    scores['RMSE'] = [np.sqrt(mean_squared_error(true, pred))]
    scores['MAE'] = [mean_absolute_error(true, pred)]
    scores['R2'] = [r2_score(true, pred)]
    scores.set_index('Model Name', inplace=True)

    return scores

def eval_classification(true, pred, name, labels=None):
    """shows classification_report and confusion matrix
    for classification model predictions.  Outputs a dataframe of metrics"""
  
    print(name, '\n')
    print(classification_report(true, pred, target_names=labels))
    ConfusionMatrixDisplay.from_predictions(true, pred, display_labels=labels, )

    plt.show()

    scores = pd.DataFrame()
    scores['Model Name'] = [name]
    scores['Precision'] = [precision_score(true, pred)]
    scores['Recall'] = [recall_score(true, pred)]
    scores['F1 Score'] = [f1_score(true, pred)]
    scores['Accuracy'] = [accuracy_score(true, pred)]
    scores.set_index('Model Name', inplace=True)

    return scores

# %%
## Create data  frame and inspect

# %%
# create dataframe and read train set
house_df = pd.read_csv('option_A_modeling_df - option_A_modeling_df.csv')

# %%
#check the data loaded correctly
house_df.head()
# Out:
#    SalePrice  SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  SqFtUpperFloor  \
# 0     400000          1590              0             0               0
# 1     474250          1390              0             0               0
# 2     667950          1010              0          1515               0
# 3     659000           660              0           540               0
# 4     656500          2310              0             0               0
#
#    SqFtTotLiving  SqFtTotBasement  SqFtFinBasement  SqFtGarageBasement  \
# 0           3180             1590             1590                   0
# 1           2200              810              810                   0
# 2           2525                0                0                   0
# 3           1820              620              620                   0
# 4           2310                0                0                   0
#
#    SqFtGarageAttached  ...  MonthSold_07  MonthSold_08  MonthSold_09  \
# ...

# %%
#look at the data
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Columns: 171 entries, SalePrice to YearSold_2020
# dtypes: float64(2), int64(169)
# memory usage: 6.4 MB

# %%
## Data Cleaning Check

# %%
# check for duplicates
house_df.duplicated().any()
# Out:
# False

# %%
#check for missing Values
house_df.isna().sum()
# Out:
# SalePrice                     0
# SqFt1stFloor                  0
# SqFtHalfFloor                 0
# SqFt2ndFloor                  0
# SqFtUpperFloor                0
# SqFtTotLiving                 0
# SqFtTotBasement               0
# SqFtFinBasement               0
# SqFtGarageBasement            0
# SqFtGarageAttached            0
# DaylightBasement              0
# SqFtOpenPorch                 0
# SqFtEnclosedPorch             0
# SqFtDeck                      0
# BrickStone                    0
# Bedrooms                      0
# BathHalfCount                 0
# Bath3qtrCount                 0
# BathFullCount                 0
# YrBuilt                       0
# PcntComplete                  0
# Longitude                     0
# Latitude                      0
# Golf Course                   0
# Other Great Outdoors          0
# Elementary School             0
# General Entertainment         0
# Park                          0
# Mexican Restaurant            0
# ...

# %% [markdown]
# - There are no missing values

# %% [markdown]
# ## Test/Train Split

# %%
# Define X and Y and complete the train test split
X = house_df.drop(columns = 'SalePrice')
y = house_df['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
# transformers
scaler2 = StandardScaler()

#Instantiate the column selectors
num_selector = make_column_selector(dtype_include='number')

#Select numerical and categorical columns:
num_columns = num_selector(X_train)

# column transformer
preprocessor = make_column_transformer(scaler2, num_columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [182], line 11
#       8 num_columns = num_selector(X_train)
#      10 # column transformer
# ---> 11 preprocessor = make_column_transformer(scaler2, num_columns)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\compose\_column_transformer.py:970, in make_column_transformer(remainder, sparse_threshold, n_jobs, verbose, verbose_feature_names_out, *transformers)
#     876 """Construct a ColumnTransformer from the given transformers.
#     877
#     878 This is a shorthand for the ColumnTransformer constructor; it does not
#    (...)
#     966                                  ['categorical_column'])])
#     967 """
#     968 # transformer_weights keyword is not passed through because the user
#     969 # would need to know the automatically generated names of the transformers
# ...

# %% [markdown]
# ## PCA transformation

# %%
# Create a scaler
scaler = StandardScaler()
# Create a PCA object that will retain 95% of the variance when transforming
pca = PCA()
# Combine the scaler and the PCA in a pipeline.
pipe = make_pipeline(scaler, pca)
# Transform the training data and check shape of new features after applying PCA
pipe.fit_transform(X_train)
# Out:
# array([[-1.25931132e+00,  1.85539412e-01,  2.41761961e-01, ...,
#         -7.46185701e-03,  2.62802661e-03, -9.81809580e-04],
#        [-3.48733354e+00,  1.37949777e+00, -1.70158404e+00, ...,
#         -5.25569930e-03,  5.54261951e-04,  2.53919926e-03],
#        [-2.31415821e+00, -7.79577304e-01, -1.60359032e-01, ...,
#         -4.44816795e-03, -2.25525475e-04,  2.77771878e-03],
#        ...,
#        [-2.33300337e+00, -5.18695955e-01,  2.82950802e-01, ...,
#          2.25568648e-03, -3.64092800e-04,  2.75294729e-03],
#        [-2.28346414e+00,  2.06698127e-02,  2.40271220e+00, ...,
#         -1.13109677e-02, -9.36601628e-03,  3.52813903e-03],
#        [-2.97367183e+00, -5.25014260e-01, -3.51629065e-01, ...,
#          2.66105155e-03,  4.98643101e-03, -1.91614115e-01]])

# %%
#check the shape
X_train.shape
# Out:
# (3702, 170)

# %%
#Using Principal Component Analysis optimize the result for modelinig
pca2 = PCA()
pca2.fit(X_train)
# Out:
# PCA()

# %%
# Lets visual the cummulative sum of the variances 

plt.style.use("seaborn")
plt.figure(figsize=(25,8))
exp_var = pd.Series(pca2.explained_variance_ratio_)

exp_var.plot(kind="bar", alpha=0.95) # plot bar chart

# Calculate the amount of variance explained added by each additional component
total = 0
var_ls = []
for x in exp_var:
    total = total+x
    var_ls.append(total)

pd.Series(var_ls).plot(marker="o", alpha=0.95) #plot line chart of increasing variances
plt.xlabel("Principle Components", fontsize="x-large")
#plt.xticks(x, [str(i) for i in y], rotation=90)
#plt.tick_params(axis='x', which='major', labelsize=10)

plt.ylabel("Percentage Variance Explained", fontsize="x-large")
plt.title("Housing Scree Plot", fontsize="xx-large")
plt.show();
# Out:
# C:\Users\Elizabeth Spreng\AppData\Local\Temp\ipykernel_26668\3933031220.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
# Lets visual the cumulative sum of the variances 

plt.style.use("seaborn")
plt.figure(figsize=(50,10))
exp_var = pd.Series(pca.explained_variance_ratio_)

exp_var.plot(kind="bar", alpha=0.7) # plot bar chart

# Calculate the amount of variance explained added by each additional component
total = 0
var_ls = []
for x in exp_var:
    total = total+x
    var_ls.append(total)

pd.Series(var_ls).plot(marker="o", alpha=0.7) #plot line chart of increasing variances
plt.xlabel("Principle Components", fontsize="x-large")
plt.ylabel("Percentage Variance Explained", fontsize="x-large")
plt.title("Housing Data Set Scree Plot", fontsize="xx-large")
plt.show();
# Out:
# C:\Users\Elizabeth Spreng\AppData\Local\Temp\ipykernel_26668\36722405.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# - Wanted to revisualize the scree plot and used https://www.datasklr.com/principal-component-analysis-and-factor-analysis/principal-component-analysis

# %%
PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.show()

# %% [markdown]
# - From the scree plots, the n_components should be 3

# %%
pca3 = PCA(n_components= 0.95)
pca3.fit(X_train)
# Lets visual the cummulative sum of the variances 

plt.style.use("seaborn")
plt.figure(figsize=(15,8))
exp_var = pd.Series(pca3.explained_variance_ratio_)

exp_var.plot(kind="bar", alpha=0.7) # plot bar chart

# Calculate the amount of variance explained added by each additional component
total = 0
var_ls = []
for x in exp_var:
    total = total+x
    var_ls.append(total)

pd.Series(var_ls).plot(marker="o", alpha=0.7) #plot line chart of increasing variances
plt.xlabel("Principle Components", fontsize="x-large")
plt.ylabel("Percentage Variance Explained", fontsize="x-large")
plt.title("Housing Dataset Scree Plot", fontsize="xx-large")
plt.show();
# Out:
# C:\Users\Elizabeth Spreng\AppData\Local\Temp\ipykernel_26668\2001030433.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# ## Fit PCA on X train

# %%
pca3=PCA(n_components = .80)
X_train_pca = pca3.fit(X_train)
X_test_pca = pca3.fit(X_test)

# %% [markdown]
# ## Create First Model

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 170

# %%
model = Sequential()

# First hidden layer
model.add(Dense(input_shape, # How many neurons you have in your first hidden layer
                input_dim = input_shape, # What is the shape of your input features (number of columns)
                activation = "relu")) # What activation function are you using?
# Second hidden layer
model.add(Dense(input_shape // 2, # How many neurons you have in your second hidden layer
                activation = "relu")) # What activation function are you using?
# Output layer
model.add(Dense(1, activation = "sigmoid")) #if linear regression: activation = "linear"
model.summary()

# Step 2: Compile
model.compile(loss = 'bce', #"mse" = mean square error, bce = binary cross entropy 
              optimizer = 'adam')

# Step 3: Fit our model
history = model.fit(X_train_pca, y_train,
                    validation_data = (X_test_pca, y_test), 
                    epochs= 30,
                    verbose = 0)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 170)               29070
#
#  dense_1 (Dense)             (None, 85)                14535
#
#  dense_2 (Dense)             (None, 1)                 86
#
# ...
# Total params: 43,691
# Trainable params: 43,691
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [195], line 19
#      15 model.compile(loss = 'bce', #"mse" = mean square error, bce = binary cross entropy
#      16               optimizer = 'adam')
#      18 # Step 3: Fit our model
# ---> 19 history = model.fit(X_train_pca, y_train,
#      20                     validation_data = (X_test_pca, y_test),
# ...

# %%
# Set Random Seeds
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# Instantiate your sequential model
model = Sequential()
# Add first hidden layer with 3 neurons THIS IS NOT THE INPUT LAYER!
# Tell Keras how to construct the input layer shape using input_dim
model.add(Dense(10, activation='relu', input_dim=X_train_pca.shape[1]))
model.add(Dense(10, activation='relu'))

# Add output layer with 1 node
model.add(Dense(1, activation='linear'))

# Check summary of network 
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [173], line 10
#       7 model = Sequential()
#       8 # Add first hidden layer with 3 neurons THIS IS NOT THE INPUT LAYER!
#       9 # Tell Keras how to construct the input layer shape using input_dim
# ---> 10 model.add(Dense(10, activation='relu', input_dim=X_train_pca.shape[1]))
#      11 model.add(Dense(10, activation='relu'))
#      13 # Add output layer with 1 node
#
# AttributeError: 'PCA' object has no attribute 'shape'

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_sc_train = scaler.transform(X_train)
X_sc_test = scaler.transform(X_test)

# %%
pca4 = PCA(n_features = 170)
pca.fit(X_train)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [191], line 1
# ----> 1 pca4 = PCA(n_features = 170 )
#       2 pca.fit(X_train)
#       4 plt.plot(np.cumsum(pca.explained_variance_ratio_))
#
# TypeError: __init__() got an unexpected keyword argument 'n_features'
